# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statistics import mode
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Sam\ChicagoCensusData.csv")

# %%
df.describe()
# Out:
#        COMMUNITY_AREA_NUMBER  PERCENT_OF_HOUSING_CROWDED  \
# count              77.000000                   78.000000
# mean               39.000000                    4.920513
# std                22.371857                    3.658981
# min                 1.000000                    0.300000
# 25%                20.000000                    2.325000
# 50%                39.000000                    3.850000
# 75%                58.000000                    6.800000
# max                77.000000                   15.800000
#
#        PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# count                         78.000000                    78.000000
# mean                          21.739744                    15.341026
# std                           11.457231                     7.499497
# min                            3.300000                     4.700000
# 25%                           13.350000                     9.200000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 9 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   COMMUNITY_AREA_NUMBER                         77 non-null     float64
#  1   COMMUNITY_AREA_NAME                           78 non-null     object
#  2   PERCENT_OF_HOUSING_CROWDED                    78 non-null     float64
#  3   PERCENT_HOUSEHOLDS_BELOW_POVERTY              78 non-null     float64
#  4   PERCENT_AGED_16__UNEMPLOYED                   78 non-null     float64
#  5   PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA  78 non-null     float64
#  6   PERCENT_AGED_UNDER_18_OR_OVER_64              78 non-null     float64
#  7   PER_CAPITA_INCOME                             78 non-null     int64
#  8   HARDSHIP_INDEX                                77 non-null     float64
# dtypes: float64(7), int64(1), object(1)
# ...

# %%
df.head()
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# 0                                          18.2
# ...

# %%
df.tail()
# Out:
#     COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# 73                               3.4                          8.7
# 74                              13.2                         15.0
# 75                              15.4                          7.1
# 76                              18.2                          9.2
# 77                              19.7                         12.9
#
#     PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# 73                                           4.3
# ...

# %%
df.dropna()
# Out:
#     COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 1                     2.0          West Ridge                         7.8
# 2                     3.0              Uptown                         3.8
# 3                     4.0      Lincoln Square                         3.4
# 4                     5.0        North Center                         0.3
# ..                    ...                 ...                         ...
# 72                   73.0   Washington Height                         1.1
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
#
#     PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# ...

# %%
df['PERCENT_HOUSEHOLDS_BELOW_POVERTY'].mean()
# Out:
# 21.739743589743597

# %%
df['PER_CAPITA_INCOME'].mean()
# Out:
# 25597.0

# %%
df['HARDSHIP_INDEX'].mean()
# Out:
# 49.506493506493506

# %%
df['PERCENT_HOUSEHOLDS_BELOW_POVERTY'].min()
# Out:
# 3.3

# %%
df['PERCENT_HOUSEHOLDS_BELOW_POVERTY'].max()
# Out:
# 56.5

# %%
df['PER_CAPITA_INCOME'].min()
# Out:
# 8201

# %%
df['PER_CAPITA_INCOME'].max()
# Out:
# 88669

# %%
df['HARDSHIP_INDEX'].min()
# Out:
# 1.0

# %%
df['HARDSHIP_INDEX'].max()
# Out:
# 98.0

# %%
df[['PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', 'PERCENT_OF_HOUSING_CROWDED']].corr()
# Out:
#                                               PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA                                      1.000000
# PERCENT_OF_HOUSING_CROWDED                                                        0.875959
#
#                                               PERCENT_OF_HOUSING_CROWDED
# PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA                    0.875959
# PERCENT_OF_HOUSING_CROWDED                                      1.000000

# %%
sns.regplot(x='PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA',y='PERCENT_OF_HOUSING_CROWDED', data=df)
# Out:
# <Axes: xlabel='PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', ylabel='PERCENT_OF_HOUSING_CROWDED'>

# %%
df[['PERCENT_OF_HOUSING_CROWDED', 'PERCENT_AGED_UNDER_18_OR_OVER_64']].corr()
# Out:
#                                   PERCENT_OF_HOUSING_CROWDED  \
# PERCENT_OF_HOUSING_CROWDED                          1.000000
# PERCENT_AGED_UNDER_18_OR_OVER_64                    0.224692
#
#                                   PERCENT_AGED_UNDER_18_OR_OVER_64
# PERCENT_OF_HOUSING_CROWDED                                0.224692
# PERCENT_AGED_UNDER_18_OR_OVER_64                          1.000000

# %%
sns.regplot(x='PERCENT_AGED_UNDER_18_OR_OVER_64',y='PERCENT_OF_HOUSING_CROWDED', data=df)
# Out:
# <Axes: xlabel='PERCENT_AGED_UNDER_18_OR_OVER_64', ylabel='PERCENT_OF_HOUSING_CROWDED'>

# %%
df[['PERCENT_HOUSEHOLDS_BELOW_POVERTY', 'PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA']].corr()
# Out:
#                                               PERCENT_HOUSEHOLDS_BELOW_POVERTY  \
# PERCENT_HOUSEHOLDS_BELOW_POVERTY                                      1.000000
# PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA                          0.424294
#
#                                               PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA
# PERCENT_HOUSEHOLDS_BELOW_POVERTY                                                  0.424294
# PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA                                      1.000000

# %%
sns.regplot(x='PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA',y='PERCENT_HOUSEHOLDS_BELOW_POVERTY', data=df)
# Out:
# <Axes: xlabel='PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', ylabel='PERCENT_HOUSEHOLDS_BELOW_POVERTY'>

# %%
df[['PERCENT_HOUSEHOLDS_BELOW_POVERTY', 'PERCENT_AGED_UNDER_18_OR_OVER_64']].corr()
# Out:
#                                   PERCENT_HOUSEHOLDS_BELOW_POVERTY  \
# PERCENT_HOUSEHOLDS_BELOW_POVERTY                          1.000000
# PERCENT_AGED_UNDER_18_OR_OVER_64                          0.435894
#
#                                   PERCENT_AGED_UNDER_18_OR_OVER_64
# PERCENT_HOUSEHOLDS_BELOW_POVERTY                          0.435894
# PERCENT_AGED_UNDER_18_OR_OVER_64                          1.000000

# %%
sns.regplot(x='PERCENT_AGED_UNDER_18_OR_OVER_64',y='PERCENT_HOUSEHOLDS_BELOW_POVERTY', data=df)
# Out:
# <Axes: xlabel='PERCENT_AGED_UNDER_18_OR_OVER_64', ylabel='PERCENT_HOUSEHOLDS_BELOW_POVERTY'>

# %%
df[[ 'PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', 'PER_CAPITA_INCOME']].corr()
# Out:
#                                               PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA                                       1.00000
# PER_CAPITA_INCOME                                                                 -0.70977
#
#                                               PER_CAPITA_INCOME
# PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA           -0.70977
# PER_CAPITA_INCOME                                       1.00000

# %%
sns.regplot(x='PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA',y='PER_CAPITA_INCOME', data=df)
# Out:
# <Axes: xlabel='PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', ylabel='PER_CAPITA_INCOME'>

# %%
df[[ 'PERCENT_AGED_UNDER_18_OR_OVER_64', 'PER_CAPITA_INCOME']].corr()
# Out:
#                                   PERCENT_AGED_UNDER_18_OR_OVER_64  \
# PERCENT_AGED_UNDER_18_OR_OVER_64                          1.000000
# PER_CAPITA_INCOME                                        -0.754844
#
#                                   PER_CAPITA_INCOME
# PERCENT_AGED_UNDER_18_OR_OVER_64          -0.754844
# PER_CAPITA_INCOME                          1.000000

# %%
sns.regplot(x='PERCENT_AGED_UNDER_18_OR_OVER_64',y='PER_CAPITA_INCOME', data=df)
# Out:
# <Axes: xlabel='PERCENT_AGED_UNDER_18_OR_OVER_64', ylabel='PER_CAPITA_INCOME'>

# %%
df[['PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', 'HARDSHIP_INDEX']].corr()
# Out:
#                                               PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA                                      1.000000
# HARDSHIP_INDEX                                                                    0.802538
#
#                                               HARDSHIP_INDEX
# PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA        0.802538
# HARDSHIP_INDEX                                      1.000000

# %%
sns.regplot(x='PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA',y='HARDSHIP_INDEX', data=df)
# Out:
# <Axes: xlabel='PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', ylabel='HARDSHIP_INDEX'>

# %%
df[['PERCENT_AGED_UNDER_18_OR_OVER_64', 'HARDSHIP_INDEX']].corr()
# Out:
#                                   PERCENT_AGED_UNDER_18_OR_OVER_64  \
# PERCENT_AGED_UNDER_18_OR_OVER_64                          1.000000
# HARDSHIP_INDEX                                            0.690844
#
#                                   HARDSHIP_INDEX
# PERCENT_AGED_UNDER_18_OR_OVER_64        0.690844
# HARDSHIP_INDEX                          1.000000

# %%
sns.regplot(x='PERCENT_AGED_UNDER_18_OR_OVER_64',y='HARDSHIP_INDEX', data=df)
# Out:
# <Axes: xlabel='PERCENT_AGED_UNDER_18_OR_OVER_64', ylabel='HARDSHIP_INDEX'>
